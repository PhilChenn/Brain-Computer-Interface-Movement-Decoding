# %%
import import_ipynb
from mp2_main import *

# %% [markdown]
# ### Test Plotting Function
# Run a test for **show_chanWeights()** function on a random (204, ) input

# %%
# Testing plotting function
arr_to_test = 100 * np.random.rand(204,)
show_chanWeights(arr_to_test)

# %%
# Set the number of points to search for the search space
n = 100

# %% [markdown]
# ## Imagery Motion Data
# ### Search space: $10^{-2} \text{ to } 10^{4}$
# For a input overt motion dataset, this line of code produces
# 1. the accuracies and the optimal regularization parameter for each of the six folds in first level CV,
# 2. the total ROC curve superimposed on all ROCs of each fold,
# 3. the channel weights plotted on a scalp surface based on pre-defined coordinates, and
# 4. the top 5 largest weight channels with a line graph representation.

# %%
cross_validated_svm_result(X_img ,y, np.logspace(-2, 4, n), show_weights=True)
# Out:
# >acc=0.825, est=0.840, cfg={'C': 0.01}
# >acc=0.925, est=0.875, cfg={'C': 0.01}
# >acc=0.850, est=0.910, cfg={'C': 0.01}
# >acc=0.900, est=0.875, cfg={'C': 0.01}
# >acc=0.850, est=0.885, cfg={'C': 0.01}
# >acc=0.900, est=0.860, cfg={'C': 0.01}
# Accuracy: 0.875 (0.035)
# 5 dominant channels:
# channel 155 (weight: -0.0029)
# channel 140 (weight: 0.0028)
# channel 151 (weight: 0.0025)
# channel 154 (weight: 0.0023)
# channel 153 (weight: 0.0022)

# %% [markdown]
# ### Search space: $10^{-8} \text{ to } 10^{-2}$

# %%
cross_validated_svm_result(X_img ,y, np.logspace(-8, -2, n))
# Out:
# >acc=0.825, est=0.885, cfg={'C': 2.477076355991714e-07}
# >acc=0.900, est=0.885, cfg={'C': 7.0548023107186455e-06}
# >acc=0.850, est=0.920, cfg={'C': 7.564633275546291e-07}
# >acc=0.900, est=0.880, cfg={'C': 8.697490026177835e-07}
# >acc=0.850, est=0.905, cfg={'C': 2.656087782946684e-06}
# >acc=0.875, est=0.905, cfg={'C': 1.232846739442066e-07}
# Accuracy: 0.867 (0.028)
# 5 dominant channels:
# channel 154 (weight: 0.0011)
# channel 140 (weight: 0.0009)
# channel 151 (weight: 0.0008)
# channel 136 (weight: -0.0008)
# channel 152 (weight: 0.0007)

# %% [markdown]
# ### Search space: $10^{4} \text{ to } 10^{10}$

# %%
cross_validated_svm_result(X_img ,y, np.logspace(4, 10, n))
# Out:
# >acc=0.825, est=0.840, cfg={'C': 10000.0}
# >acc=0.925, est=0.875, cfg={'C': 10000.0}
# >acc=0.850, est=0.910, cfg={'C': 10000.0}
# >acc=0.900, est=0.875, cfg={'C': 10000.0}
# >acc=0.850, est=0.885, cfg={'C': 10000.0}
# >acc=0.900, est=0.860, cfg={'C': 10000.0}
# Accuracy: 0.875 (0.035)
# 5 dominant channels:
# channel 155 (weight: -0.0029)
# channel 140 (weight: 0.0028)
# channel 151 (weight: 0.0025)
# channel 154 (weight: 0.0023)
# channel 153 (weight: 0.0022)

# %% [markdown]
# ## Overt Motion Data
# ### Search space: $10^{-2} \text{ to } 10^{4}$
# For a input overt motion dataset, this line of code produces
# 1. the accuracies and the optimal regularization parameter for each of the six folds in first level CV,
# 2. the total ROC curve superimposed on all ROCs of each fold,
# 3. the channel weights plotted on a scalp surface based on pre-defined coordinates, and
# 4. the top 5 largest weight channels with a line graph representation.

# %%
cross_validated_svm_result(X_overt ,y, np.logspace(-2, 4, n))
# Out:
# >acc=0.950, est=0.935, cfg={'C': 0.01}
# >acc=0.900, est=0.930, cfg={'C': 0.01}
# >acc=0.975, est=0.935, cfg={'C': 0.01}
# >acc=0.925, est=0.945, cfg={'C': 0.01}
# >acc=1.000, est=0.935, cfg={'C': 0.01}
# >acc=0.950, est=0.955, cfg={'C': 0.01}
# Accuracy: 0.950 (0.032)
# 5 dominant channels:
# channel 140 (weight: 0.0014)
# channel 154 (weight: 0.0013)
# channel 100 (weight: 0.0011)
# channel 155 (weight: -0.0011)
# channel 136 (weight: -0.0011)

# %% [markdown]
# ### Search space: $10^{-8} \text{ to } 10^{-2}$

# %%
cross_validated_svm_result(X_overt ,y, np.logspace(-8, -2, n))
# Out:
# >acc=0.975, est=0.940, cfg={'C': 8.697490026177835e-07}
# >acc=0.900, est=0.940, cfg={'C': 2.0092330025650458e-06}
# >acc=0.975, est=0.945, cfg={'C': 8.697490026177835e-07}
# >acc=0.975, est=0.950, cfg={'C': 1.1497569953977357e-06}
# >acc=1.000, est=0.950, cfg={'C': 8.697490026177835e-07}
# >acc=0.950, est=0.955, cfg={'C': 1.1497569953977357e-06}
# Accuracy: 0.963 (0.031)
# 5 dominant channels:
# channel 140 (weight: 0.0010)
# channel 154 (weight: 0.0010)
# channel 155 (weight: -0.0009)
# channel 136 (weight: -0.0009)
# channel 128 (weight: -0.0009)

# %% [markdown]
# ### Search space: $10^{4} \text{ to } 10^{10}$

# %%
cross_validated_svm_result(X_overt ,y, np.logspace(4, 10, n))
# Out:
# >acc=0.950, est=0.935, cfg={'C': 10000.0}
# >acc=0.900, est=0.930, cfg={'C': 10000.0}
# >acc=0.975, est=0.935, cfg={'C': 10000.0}
# >acc=0.925, est=0.945, cfg={'C': 10000.0}
# >acc=1.000, est=0.935, cfg={'C': 10000.0}
# >acc=0.950, est=0.955, cfg={'C': 10000.0}
# Accuracy: 0.950 (0.032)
# 5 dominant channels:
# channel 140 (weight: 0.0014)
# channel 154 (weight: 0.0013)
# channel 100 (weight: 0.0011)
# channel 155 (weight: -0.0011)
# channel 136 (weight: -0.0011)
